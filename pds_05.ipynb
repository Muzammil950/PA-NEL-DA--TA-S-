# %%
import pandas as pd

# %%
data = {"a" : [1,2,3,4],
        "b" : [4,5,6,7],
        "C" : ["sudh","hitesh","asif","pandu"]}

# %%
pd.DataFrame(data)
# Out:
#    a  b       C
# 0  1  4    sudh
# 1  2  5  hitesh
# 2  3  6    asif
# 3  4  7   pandu

# %%
df=pd.DataFrame(data)

# %%
df.set_index("a")
# Out:
#    b       C
# a
# 1  4    sudh
# 2  5  hitesh
# 3  6    asif
# 4  7   pandu

# %%
df.set_index("a",inplace= True)

# %%
df
# Out:
#    b       C
# a
# 1  4    sudh
# 2  5  hitesh
# 3  6    asif
# 4  7   pandu

# %%
df.reset_index()
# Out:
#    a  b       C
# 0  1  4    sudh
# 1  2  5  hitesh
# 2  3  6    asif
# 3  4  7   pandu

# %%
df
# Out:
#    b       C
# a
# 1  4    sudh
# 2  5  hitesh
# 3  6    asif
# 4  7   pandu

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#    a  b       C
# 0  1  4    sudh
# 1  2  5  hitesh
# 2  3  6    asif
# 3  4  7   pandu

# %%
data1 = {"a" : [1,2,3,4],
        "b" : [4,5,6,7],
        "C" : ["sudh","hitesh","asif","pandu"]}
pd.DataFrame(data1,index = ['a','b','c','d'])
# Out:
#    a  b       C
# a  1  4    sudh
# b  2  5  hitesh
# c  3  6    asif
# d  4  7   pandu

# %%
df1 = pd.DataFrame(data1,index = ['a','b','c','d'])

# %%
df1.reindex(['b','c','d','a'])
# Out:
#    a  b       C
# b  2  5  hitesh
# c  3  6    asif
# d  4  7   pandu
# a  1  4    sudh

# %%
df1.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x000001A675BAA460>

# %%
for i in df1.iterrows():
    print(i)
# Out:
# ('a', a       1
# b       4
# C    sudh
# Name: a, dtype: object)
# ('b', a         2
# b         5
# C    hitesh
# Name: b, dtype: object)
# ('c', a       3
# b       6
# C    asif
# Name: c, dtype: object)
# ('d', a        4
# b        7
# C    pandu
# Name: d, dtype: object)

# %%
for  i,j in df1.iterrows():
    print(i,j)
# Out:
# a a       1
# b       4
# C    sudh
# Name: a, dtype: object
# b a         2
# b         5
# C    hitesh
# Name: b, dtype: object
# c a       3
# b       6
# C    asif
# Name: c, dtype: object
# d a        4
# b        7
# C    pandu
# Name: d, dtype: object

# %%
for i in df1.items():
    print(i)
# Out:
# ('a', a    1
# b    2
# c    3
# d    4
# Name: a, dtype: int64)
# ('b', a    4
# b    5
# c    6
# d    7
# Name: b, dtype: int64)
# ('C', a      sudh
# b    hitesh
# c      asif
# d     pandu
# Name: C, dtype: object)

# %%
list(df['a'])
# Out:
# [1, 2, 3, 4]

# %%
[i for i in df['a']]
# Out:
# [1, 2, 3, 4]

# %%
def test(x):
        return x.sum()
df1.apply(test)
# Out:
# a                     10
# b                     22
# C    sudhhiteshasifpandu
# dtype: object

# %%
df
# Out:
#    a  b       C
# 0  1  4    sudh
# 1  2  5  hitesh
# 2  3  6    asif
# 3  4  7   pandu

# %%
df[['a','b']]
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6
# 3  4  7

# %%
df1 = df[['a','b']]

# %%
df1.applymap(lambda x : x**2)
# Out:
# C:\Users\SHAIKH\AppData\Local\Temp\ipykernel_5712\1241945342.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df1.applymap(lambda x : x**2)
#     a   b
# 0   1  16
# 1   4  25
# 2   9  36
# 3  16  49

# %%
df
# Out:
#    a  b       C
# 0  1  4    sudh
# 1  2  5  hitesh
# 2  3  6    asif
# 3  4  7   pandu

# %%
df.sort_values('C')
# Out:
#    a  b       C
# 2  3  6    asif
# 1  2  5  hitesh
# 3  4  7   pandu
# 0  1  4    sudh

# %%
pd.set_option("display.max_colwidth",400)
df3 = pd.DataFrame({"Desc" : ["Pandas is an open-source Python library for data manipulation and analysis, built on top of the NumPy library. It provides powerful, easy-to-use data structures like the Series (1D labeled array) and DataFrame (2D table), which simplify working with labeled and tabular data. Pandas is used for cleaning, transforming, merging, and analyzing datasets, and is widely used in data science, machine learning, and statistics", "iam a i" , "who is this "," how do you do"]})

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                               Desc
# 0  Pandas is an open-source Python library for data manipulation and analysis, built on top of the NumPy library. It provides powerful, easy-to-use data structures like the Series (1D labeled array) and DataFrame (2D table), which simplify working with labeled and tabular data. Pandas is used for cleaning, transforming, merging, and analyzing datasets, and is widely used in data science, machine ...
# ...

# %%
df3['len'] = df3['Desc'].apply(len)

# %%
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                               Desc  \
# 0  Pandas is an open-source Python library for data manipulation and analysis, built on top of the NumPy library. It provides powerful, easy-to-use data structures like the Series (1D labeled array) and DataFrame (2D table), which simplify working with labeled and tabular data. Pandas is used for cleaning, transforming, merging, and analyzing datasets, and is widely used in data science, machine ...
# ...

# %%
import pandas as pd

# %%
df['a'].mean()
# Out:
# np.float64(2.5)

# %%
df['a'].median()
# Out:
# np.float64(2.5)

# %%
df['a'].mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
df['a'].std()
# Out:
# np.float64(1.2909944487358056)

# %%
df['a'].sum()
# Out:
# np.int64(10)

# %%
df['a'].min()
# Out:
# np.int64(1)

# %%
df['a'].max()
# Out:
# np.int64(4)

# %%
df['a'].var()
# Out:
# np.float64(1.6666666666666667)

# %% [markdown]
# # Window function

# %%
df4 = pd.DataFrame({'a' : [3,4,5,2,1,3,4,5,6]})

# %%
df4
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
df4['a'].rolling(window=1).mean()
# Out:
# 0    3.0
# 1    4.0
# 2    5.0
# 3    2.0
# 4    1.0
# 5    3.0
# 6    4.0
# 7    5.0
# 8    6.0
# Name: a, dtype: float64

# %%
df4['a'].rolling(window=2).mean()
# Out:
# 0    NaN
# 1    3.5
# 2    4.5
# 3    3.5
# 4    1.5
# 5    2.0
# 6    3.5
# 7    4.5
# 8    5.5
# Name: a, dtype: float64

# %%
df4['a'].rolling(window=3).mean()
# Out:
# 0         NaN
# 1         NaN
# 2    4.000000
# 3    3.666667
# 4    2.666667
# 5    2.000000
# 6    2.666667
# 7    4.000000
# 8    5.000000
# Name: a, dtype: float64

# %% [markdown]
# # Date function

# %%
date = pd.date_range(start = '2023-04-23', end = '2023-06-23')

# %%
date
# Out:
# DatetimeIndex(['2023-04-23', '2023-04-24', '2023-04-25', '2023-04-26',
#                '2023-04-27', '2023-04-28', '2023-04-29', '2023-04-30',
#                '2023-05-01', '2023-05-02', '2023-05-03', '2023-05-04',
#                '2023-05-05', '2023-05-06', '2023-05-07', '2023-05-08',
#                '2023-05-09', '2023-05-10', '2023-05-11', '2023-05-12',
#                '2023-05-13', '2023-05-14', '2023-05-15', '2023-05-16',
#                '2023-05-17', '2023-05-18', '2023-05-19', '2023-05-20',
#                '2023-05-21', '2023-05-22', '2023-05-23', '2023-05-24',
#                '2023-05-25', '2023-05-26', '2023-05-27', '2023-05-28',
#                '2023-05-29', '2023-05-30', '2023-05-31', '2023-06-01',
#                '2023-06-02', '2023-06-03', '2023-06-04', '2023-06-05',
#                '2023-06-06', '2023-06-07', '2023-06-08', '2023-06-09',
#                '2023-06-10', '2023-06-11', '2023-06-12', '2023-06-13',
# ...

# %%
df_date = pd.DataFrame({'date' : date})

# %%
df_date
# Out:
#          date
# 0  2023-04-23
# 1  2023-04-24
# 2  2023-04-25
# 3  2023-04-26
# 4  2023-04-27
# ..        ...
# 57 2023-06-19
# 58 2023-06-20
# 59 2023-06-21
# 60 2023-06-22
# 61 2023-06-23
#
# [62 rows x 1 columns]

# %%
df_date.dtypes
# Out:
# date    datetime64[ns]
# dtype: object

# %%
df7 = pd.DataFrame({'date' : ['2023-06-23','2023-06-22','2023-06-21']})

# %%
df7
# Out:
#          date
# 0  2023-06-23
# 1  2023-06-22
# 2  2023-06-21

# %%
df7.dtypes
# Out:
# date    object
# dtype: object

# %%
df7['update_date'] = pd.to_datetime(df7['date'])

# %%
df7
# Out:
#          date update_date
# 0  2023-06-23  2023-06-23
# 1  2023-06-22  2023-06-22
# 2  2023-06-21  2023-06-21

# %%
df7.dtypes
# Out:
# date                   object
# update_date    datetime64[ns]
# dtype: object

# %%
df7['year'] = df7['update_date'].dt.year

# %%
df7
# Out:
#          date update_date  year
# 0  2023-06-23  2023-06-23  2023
# 1  2023-06-22  2023-06-22  2023
# 2  2023-06-21  2023-06-21  2023

# %%
df7['day'] = df7['update_date'].dt.day

# %%
df7
# Out:
#          date update_date  year  day
# 0  2023-06-23  2023-06-23  2023   23
# 1  2023-06-22  2023-06-22  2023   22
# 2  2023-06-21  2023-06-21  2023   21

# %%
df7['month'] = df7['update_date'].dt.month

# %%
df7
# Out:
#          date update_date  year  day  month
# 0  2023-06-23  2023-06-23  2023   23      6
# 1  2023-06-22  2023-06-22  2023   22      6
# 2  2023-06-21  2023-06-21  2023   21      6

# %% [markdown]
# # TimeDelta

# %%
import pandas as pd

# %%
pd.Timedelta(days=1)
# Out:
# Timedelta('1 days 00:00:00')

# %%
pd.Timedelta(days=1,hours=5)
# Out:
# Timedelta('1 days 05:00:00')

# %%
pd.Timedelta(days=1,hours=5,minutes=45)
# Out:
# Timedelta('1 days 05:45:00')

# %%
dt = pd.to_datetime('2023-06-20')

# %%
td = pd.Timedelta(days=1)

# %%
td + dt
# Out:
# Timestamp('2023-06-21 00:00:00')

# %% [markdown]
# # Categorical data

# %%
data = ['suddu','asif','arif','asif','pandu','pandu','asif']

# %%
pd.Categorical(data)
# Out:
# ['suddu', 'asif', 'arif', 'asif', 'pandu', 'pandu', 'asif']
# Categories (4, object): ['arif', 'asif', 'pandu', 'suddu']

# %%
cat = pd.Categorical(data)

# %%
cat.value_counts()
# Out:
# arif     1
# asif     3
# pandu    2
# suddu    1
# Name: count, dtype: int64

# %% [markdown]
# # Visualization

# %%
d = pd.Series([1,2,3,3,5,6,6,8])

# %%
d
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# 4    5
# 5    6
# 6    6
# 7    8
# dtype: int64

# %%
d.plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame({'a':[3,4,5,6,7],
                   'b': [4,5,6,7,8]})

# %%
df
# Out:
#    a  b
# 0  3  4
# 1  4  5
# 2  5  6
# 3  6  7
# 4  7  8

# %%
df.plot(x='a',y='b')
# Out:
# <Axes: xlabel='a'>

# %%
df.plot.scatter(x='a',y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
p = pd.Series([1,2,3,3,5,6,6,8])

# %%
p.plot.pie()
# Out:
# <Axes: >
